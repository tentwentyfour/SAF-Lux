# %% [markdown]
# # Import necessary python libraries

# %%
from wikidataintegrator import wdi_core, wdi_login
from getpass import getpass
import pandas as pd
import rdflib
import sys
import traceback

# %% [raw]
# # Get CIDOC-CRM

# %%
cidoc = rdflib.Graph()
cidoc.load("https://raw.githubusercontent.com/erlangen-crm/ecrm/master/ecrm_current.owl", format="xml")

# %% [markdown]
# # Login to Wikibase

# %%
wikibase = "https://cidocoption1a.wiki.opencura.com/"
api = "https://cidocoption1a.wiki.opencura.com/w/api.php"
sparql = "https://cidocoption1a.wiki.opencura.com/query/sparql"
entityUri = wikibase.replace("https:", "http:")+"entity/"

WBUSER = "Andrawaag"
WBPASS = getpass()
login = wdi_login.WDLogin(WBUSER, WBPASS, mediawiki_api_url=api)
# Out:
# ········

# %% [markdown]
# # define python functions

# %%
def createProperty(login=login, wdprop=None, lulabel="", enlabel="", frlabel="", delabel="", description="", property_datatype=""):
    if wdprop== None:
        s = []
    else:
        s = [wdi_core.WDUrl(wdprop, prop_nr="P1")]
    localEntityEngine = wdi_core.WDItemEngine.wikibase_item_engine_factory(api,sparql)
    item = localEntityEngine(data=s)
    #item.set_label(lulabel, lang="lu")
    item.set_label(enlabel, lang="en")
    item.set_label(delabel, lang="de")
    item.set_label(frlabel, lang="fr")
    item.set_description(description, lang="en")
    
    print(item.write(login, entity_type="property", property_datatype=property_datatype))

datatype_map = {'http://wikiba.se/ontology#CommonsMedia': 'commonsMedia',
                'http://wikiba.se/ontology#ExternalId': 'external-id',
                'http://wikiba.se/ontology#GeoShape': 'geo-shape',
                'http://wikiba.se/ontology#GlobeCoordinate': 'globe-coordinate',
                'http://wikiba.se/ontology#Math': 'math',
                'http://wikiba.se/ontology#Monolingualtext': 'monolingualtext',
                'http://wikiba.se/ontology#Quantity': 'quantity',
                'http://wikiba.se/ontology#String': 'string',
                'http://wikiba.se/ontology#TabularData': 'tabular-data',
                'http://wikiba.se/ontology#Time': 'time',
                '<http://wikiba.se/ontology#Edtf>': 'edtf',
                'http://wikiba.se/ontology#Url': 'url',
                'http://wikiba.se/ontology#WikibaseItem': 'wikibase-item',
                'http://wikiba.se/ontology#WikibaseProperty': 'wikibase-property'}

# %% [markdown]
# # predefined properties from rdfs, skos, etc

# %%
# skos:exact match
createProperty(login, lulabel="Ënnerklass vu(n)", 
                      enlabel="exact match",
                      frlabel="correspondance exacte",
                      delabel="exakte Übereinstimmung",
                      description="mapping",
                      property_datatype="url")
# instance of
createProperty(login, lulabel="", 
                      enlabel="instance of",
                      frlabel="instance de",
                      delabel="ist ein(e)",
                      property_datatype="wikibase-item")
# subclass of
## TODO work on multilangauge descriptions 
## 
createProperty(login, lulabel="Ënnerklass vu(n)", 
                      enlabel="subclass of",
                      frlabel="sous-classe de",
                      delabel="Unterklasse von",
                      property_datatype="wikibase-item")
#domain 
createProperty(login, lulabel="", 
                      enlabel="domain",
                      frlabel="domaine",
                      delabel="domain",
                      property_datatype="wikibase-item")
#range
createProperty(login, lulabel="", 
                      enlabel="range",
                      frlabel="intervalle",
                      delabel="reichweite",
                      property_datatype="wikibase-item")
#subPropertyOf
createProperty(login, lulabel="", 
                      enlabel="subPropertyOf",
                      frlabel="sous-propriété de",
                      delabel="untereigenschaft von",
                      property_datatype="wikibase-item")
#inverseOf
createProperty(login, lulabel="", 
                      enlabel="inverse of",
                      frlabel="inverse de",
                      delabel="invers von",
                      property_datatype="wikibase-item")

# %% [markdown]
# # Predefined classes

# %%
# class item
localEntityEngine = wdi_core.WDItemEngine.wikibase_item_engine_factory(api,sparql)
item = localEntityEngine(new_item=True)
item.set_label("Class", lang="en")
item.set_aliases(["Owl:Class"], lang="en")
item.write(login)

# property item
item = localEntityEngine(new_item=True)
item.set_label("Property", lang="en")
item.set_aliases(["owl:ObjectProperty"], lang="en")
item.write(login)

# %%
qid = dict()

# %% [markdown]
# # Create Wikibase items for CIDOC-CRM classes (Erlanger)

# %%
qid = dict()
query = "SELECT ?cidoc ?label WHERE {?cidoc rdf:type <http://www.w3.org/2002/07/owl#Class> ; rdfs:label ?label .}"
for row in cidoc.query(query):
    #print(str(row[0]), str(row[1]), " ".join(str(row[1]).split(" ")[1:]))
    try:
        statements=[]
        statements.append(wdi_core.WDItemID(value="Q1", prop_nr="P2"))
        statements.append(wdi_core.WDUrl(value=str(row[0]), prop_nr="P1"))
        item = localEntityEngine(new_item=True, data=statements)
        item.set_label(" ".join(str(row[1]).split(" ")), lang="en")
        #item.set_aliases([str(row[1]), str(row[1]).replace(" ", "_")], lang="en")
        print(item.write(login))
    except:
        print("tjoep")

# %% [markdown]
# # Create Wikidata items for CIDOC CRM ObjectProperties (Erlanger)
# # The properties are created as ITEMS on Wikibase

# %%
import pprint

prefix = entityUri.replace("entity","prop/direct")
query = "PREFIX wdt: <"+prefix+"> SELECT * WHERE {?item wdt:P1 ?uri .}"
for index, row in wdi_core.WDItemEngine.execute_sparql_query(query, as_dataframe = True, endpoint=sparql).iterrows():
    qid[row["uri"]] =row["item"].replace(entityUri, "")
pprint.pprint(qid)
print(query)

# %%
localEntityEngine = wdi_core.WDItemEngine.wikibase_item_engine_factory(api,sparql)
#propertyClasses
query = "SELECT ?cidoc ?label WHERE {?cidoc rdf:type <http://www.w3.org/2002/07/owl#ObjectProperty> ; rdfs:label ?label .}"
for row in cidoc.query(query):
    if str(row[0]) not in qid.keys():
        print(row[0])
        print(str(row[0]), str(row[1]), " ".join(str(row[1]).split(" ")[1:]))
        statements=[]
        statements.append(wdi_core.WDItemID(value="Q2", prop_nr="P2"))
        statements.append(wdi_core.WDUrl(value=str(row[0]), prop_nr="P1"))
        item = localEntityEngine(new_item=True, data=statements)
        item.set_label(" ".join(str(row[1]).split(" ")), lang="en")
        #item.set_aliases([str(row[1]), str(row[1]).replace(" ", "_")], lang="en")
        try:
            print(item.write(login))
        except:
            print("ERROR: "+str(row[1]))
            continue
    else:
        print("correct")

# %% [markdown]
# ## Add domain from CIDOC crm with local proparty

# %%
query = """SELECT DISTINCT ?cidoc ?domain  WHERE {
                 # ?cidoc rdf:type <http://www.w3.org/2002/07/owl#ObjectProperty> ; 
                        rdfs:domain ?domain .}"""
for row in cidoc.query(query):
    try:
        print(qid[str(row["cidoc"])].replace(entityUri, ""))
        localEntityEngine = wdi_core.WDItemEngine.wikibase_item_engine_factory(api,sparql)
        statements=[]
        statements.append(wdi_core.WDItemID(value=qid[str(row["domain"])].replace(entityUri, ""), prop_nr="P4"))
        item = localEntityEngine(wd_item_id=qid[str(row["cidoc"])].replace(entityUri, ""), data=statements)
        print(item.write(login))
    except Exception as e:
        print(traceback.format_exc())
        continue

# %% [markdown]
# ## Add range from CIDOC crm with local proparty

# %%
query = """SELECT DISTINCT ?cidoc ?range  WHERE {
                 # ?cidoc rdf:type <http://www.w3.org/2002/07/owl#ObjectProperty> ; 
                        rdfs:range ?range .}"""
for row in cidoc.query(query):
    try:
        print(qid[str(row["cidoc"])])
        localEntityEngine = wdi_core.WDItemEngine.wikibase_item_engine_factory(api,sparql)
        statements=[]
        statements.append(wdi_core.WDItemID(value=qid[str(row["range"])].replace("http://safcidoc2.wiki.opencura.com/entity/", ""), prop_nr="P5"))
        item = localEntityEngine(wd_item_id=qid[str(row["cidoc"])].replace("http://safcidoc2.wiki.opencura.com/entity/", ""), data=statements)
        print(item.write(login))
    except:
        str(row["cidoc"])
        continue

# %%
query = """SELECT DISTINCT ?cidoc ?subPropertyOf  WHERE {
                 # ?cidoc rdf:type <http://www.w3.org/2002/07/owl#ObjectProperty> ; 
                        rdfs:subPropertyOf ?subPropertyOf ;
                        rdfs:range ?range .}"""
for row in cidoc.query(query):
    try:
        print(qid[str(row["cidoc"])])
        localEntityEngine = wdi_core.WDItemEngine.wikibase_item_engine_factory(api,sparql)
        statements=[]
        statements.append(wdi_core.WDItemID(value=qid[str(row["subPropertyOf"])], prop_nr="P6"))
        item = localEntityEngine(wd_item_id=qid[str(row["cidoc"])], data=statements)
        print(item.write(login))
    except:
        continue

# %%
query = """SELECT DISTINCT ?cidoc ?inverseOf  WHERE {
                 # ?cidoc rdf:type <http://www.w3.org/2002/07/owl#ObjectProperty> ; 
                        owl:inverseOf ?inverseOf ;
                        rdfs:range ?range .}"""
for row in cidoc.query(query):
    try:
        print(qid[str(row["cidoc"])])
        localEntityEngine = wdi_core.WDItemEngine.wikibase_item_engine_factory(api,sparql)
        statements=[]
        statements.append(wdi_core.WDItemID(value=qid[str(row["inverseOf"])], prop_nr="P7"))
        item = localEntityEngine(wd_item_id=qid[str(row["cidoc"])], data=statements)
        print(item.write(login))
    except:
        continue

# %% [markdown]
# # Import SAF properties as described in DM_SAF

# %% [markdown]
# ## Import the Excel sheet that contains the LUX Saf view of CIDOC-CRM

# %%
model_def = pd.read_excel("DM_SAF_vers.1.1.3.xlsx", header=1)
model_def
# Out:
#                              Field - AF                          Deutsch  \
# 0                                  Name                            namen
# 1                                  Type                     Namensformat
# 2                            Numeration                     Nummerierung
# 3                                 Title                            Titel
# 4                            Birth date                     Geburtsdatum
# 5                           Birth place                       Geburtsort
# 6                            Death date                      Sterbedatum
# 7                           Death place                    Ort des Todes
# 8                               Gender                       Geschlecht
# 9                    Profession  - type                   Art des Berufs
# 10               Profession - beginning                     Anfangsdatum
# 11                     Profession - end                        Enddatum
# 12                     Activity - type                 Art der Aktivität
# 13                Activity - beginning                  Anfangsdatum_akt
# 14                       Activity - end                     Enddatum_akt
# 15         Source of information - text                           Quelle
# 16         Source of information - type                       Quellentyp
# 17          source of information - url         Informationsquelle (URL)
# 18                                Notes                           Notiz
# 19              Notes - internal/public                         Notiztyp
# 20    External standard identifier - ID                               ID
# 21  External standard identifier - name                        ID Quelle
# 22         Internal standard identifier          Interne Standardkennung
# 23   Source of data (Institution codes)  Datenquelle (Institutionscodes)
# 24                     Date of creation                     Erstelldatum
# 25             Date of the modification               Datum der Änderung
# 26               Author of modification                       Bearbeiter
# 27                       Status of data                           Status
#
#                                English  \
# 0                                 name
# 1                          name format
# 2                           numeration
# 3                                title
# 4                        date of birth
# 5                       place of birth
# 6                        date of death
# 7                       place of death
# 8                              gender
# 9                   type of profession
# 10                   date of beginning
# 11                            end date
# 12                    type of activity
# 13              start date of activity
# 14                end date of activity
# 15        source of information (text)
# 16                     type of source
# 17         source of information (url)
# 18                                note
# 19                           note type
# 20                                  ID
# 21                           ID Source
# 22        Internal standard identifier
# 23  source of data (institution codes)
# 24                    date of creation
# 25                date of modification
# 26              author of modification
# 27                             status
#
#                                   français                     Domain  \
# 0                                      nom                 E21 Person
# 1                            format du nom        E90 Symbolic Object
# 2                               numeration                 E21 Person
# 3                                    titre                 E21 Person
# 4                        date de naissance                 E21 Person
# 5                       place de naissance                 E21 Person
# 6                            date de décès                 E21 Person
# 7                       place de naissance                 E21 Person
# 8                                     sexe                 E21 Person
# 9                       type de profession                 E21 Person
# 10                           date de début                E7 Activity
# 11                             date de fin                E7 Activity
# 12                         type d'activité                 E21 Person
# 13                       date de début_act                E7 Activity
# 14                         date de fin_act                E7 Activity
# 15                    source d'information                 E21 Person
# 16            type de source d'information               E31 document
# 17              source d'information (url)                 E21 Person
# 18                                    note                 E21 Person
# 19                            type de note                 E62 String
# 20                                      ID                 E21 Person
# 21                               Source ID             E42 Identifier
# 22            Identifiant standard interne                 E21 Person
# 23  source des données (codes institution)   E89 Propositional Object
# 24                        date de création   E89 Propositional Object
# 25                    date de modification   E89 Propositional Object
# 26                                  editor  E13 Attribute assignement
# 27                                  statut   E89 Propositional Object
#
#                         Property                     Range Required : Y/N  \
# 0               is a subclass of                 E39 Actor            NaN
# 1                    P2 has type                  E55 Type              Y
# 2            P1 is identified by     E82 Actor appellation              Y
# 3            P1 is identified by     E82 Actor appellation              Y
# 4                   P98 was born                 E67 Birth              Y
# 5                  P98i was born                 E67 Birth              N
# 6                  P100i died in                 E69 Death              N
# 7                   P100 died in                 E69 Death              N
# 8                    P2 has type                  E55 Type              Y
# 9                 P14i performed               E7 Activity              N
# 10              P4 has time-span             E52 Time-Span              N
# 11              P4 has time-span             E52 Time-span              N
# 12                P14i performed               E7 Activity              N
# 13              P4 has time-span             E52 Time-Span              N
# 14              P4 has time-span             E52 Time-Span              N
# 15         P70i is documented in              E31 document              Y
# 16                   P2 has type                  E55 Type              N
# 17         P70i is documented in              E31 document              N
# 18                   P3 has note                E62 String              N
# 19                   P2 has type                  E55 Type              Y
# 20  P48 has preferred identifier            E42 Identifier              N
# 21                   P2 has type                  E55 Type              Y
# 22        P67i is referred to by  E89 Propositional Object              Y
# 23           P94i was created by              E65 Creation              Y
# 24           P94i was created by              E65 Creation              Y
# 25         P141i was assigned by  E13 Attribute assignment              N
# 26            P14 carried out by                 E39 Actor              Y
# 27                   P2 has type                  E55 Type              Y
#
#    Repeated : Y/N        Data type  ... Public display            Example 1  \
# 0             NaN  monolingualtext  ...            NaN                  NaN
# 1               N    wikibase-item  ...            NaN                    1
# 2               N    wikibase-item  ...            NaN                  NaN
# 3               N  monolingualtext  ...            NaN                  NaN
# 4               N             edtf  ...            NaN                  NaN
# 5               N             edtf  ...            NaN                  NaN
# 6               N             edtf  ...            NaN                  NaN
# 7               N             edtf  ...            NaN                  NaN
# 8               N    wikibase-item  ...            NaN                    1
# 9               Y  monolingualtext  ...            NaN                  NaN
# 10              N             edtf  ...            NaN                  NaN
# 11              N             edtf  ...            NaN                  NaN
# 12              Y  monolingualtext  ...            NaN                  NaN
# 13              N             edtf  ...            NaN                 1951
# 14              N             edtf  ...            NaN                 1994
# 15              Y           string  ...            NaN     lb.wikipedia.org
# 16              Y   wikibase-item   ...            NaN                  NaN
# 17              N              url  ...            NaN                  NaN
# 18              Y  monolingualtext  ...            NaN                  NaN
# 19              Y   wikibase-item   ...            NaN                  NaN
# 20              Y           string  ...            NaN  0000 0004 8298 7004
# 21              N   wikibase-item   ...            NaN                 ISNI
# 22              N      external-id  ...            NaN                  NaN
# 23              Y    wikibase-item  ...            NaN                  NaN
# 24              N             edtf  ...            NaN                  NaN
# 25              Y             edtf  ...            NaN                  NaN
# 26              Y          string   ...            NaN                  NaN
# 27              N   wikibase-item   ...            NaN                  NaN
#
#                 Example 2 Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 0                     NaN         NaN         NaN         NaN
# 1                       0         NaN         NaN         NaN
# 2                     NaN         NaN         NaN         NaN
# 3                     NaN         NaN         NaN         NaN
# 4                     NaN         NaN         NaN         NaN
# 5                     NaN         NaN         NaN         NaN
# 6                     NaN         NaN         NaN         NaN
# 7                     NaN         NaN         NaN         NaN
# 8                       2         NaN         NaN         NaN
# 9                     NaN         NaN         NaN         NaN
# 10                    NaN         NaN         NaN         NaN
# 11                    NaN         NaN         NaN         NaN
# 12                    NaN         NaN         NaN         NaN
# 13                   1919         NaN         NaN         NaN
# 14                   1964         NaN         NaN         NaN
# 15  Site web monarchie.lu         NaN         NaN         NaN
# 16                    NaN         NaN         NaN         NaN
# 17                    NaN         NaN         NaN         NaN
# 18                    NaN         NaN         NaN         NaN
# 19                    NaN         NaN         NaN         NaN
# 20    0000 0003 8244 0415         NaN         NaN         NaN
# 21                   ISNI         NaN         NaN         NaN
# 22                    NaN         NaN         NaN         NaN
# 23                    NaN         NaN         NaN         NaN
# 24                    NaN         NaN         NaN         NaN
# 25                    NaN         NaN         NaN         NaN
# 26                    NaN         NaN         NaN         NaN
# 27                    NaN         NaN         NaN         NaN
#
#                   Note  Minimum set of fields   \
# 0                    /                       /
# 1           CL3 -final                       Y
# 2                    /                       /
# 3                    /                       /
# 4                    /                       /
# 5                    /                       /
# 6                    /                       /
# 7                    /                       /
# 8                  CL4                       Y
# 9                    /                       /
# 10                   /                       /
# 11                   /                       /
# 12                   /                       /
# 13                   /                       /
# 14                   /                       /
# 15                   /                       Y
# 16  CL6- to be defined                       /
# 17                 NaN                     NaN
# 18                   /                       /
# 19                   /                       /
# 20                   /                       /
# 21                   /                       /
# 22                   /                       /
# 23                   /                      YS
# 24                   /                       /
# 25                   /                       /
# 26                   /                      YS
# 27           CL5 final                      YS
#
#                                               Notes Unnamed: 26
# 0                                               NaN         NaN
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                               NaN         NaN
# 4                                               NaN         NaN
# 5                                               NaN         NaN
# 6                                               NaN         NaN
# 7                                               NaN         NaN
# 8                                               NaN         NaN
# 9                                               NaN         NaN
# 10       Level of granularity in definition by WP 6         NaN
# 11       Level of granularity in definition by WP 6         NaN
# 12                                              NaN         NaN
# 13       Level of granularity in definition by WP 6         NaN
# 14       Level of granularity in definition by WP 6         NaN
# 15  missing date of consultation for online sources         NaN
# 16                                when and by whom?         NaN
# 17                                              NaN         NaN
# 18                                              NaN         NaN
# 19                                              NaN         NaN
# 20                                              NaN         NaN
# 21                                              NaN         NaN
# 22                                              NaN         NaN
# 23                                              NaN         NaN
# 24                                              NaN         NaN
# 25                                              NaN         NaN
# 26                                              NaN         NaN
# 27                                              NaN         NaN
#
# [28 rows x 27 columns]

# %% [markdown]
# # extract property definitions
# Here only the fields needed containing the mapping rules are being extracted. This is a step allowing close inspection, later it can be removed and the subsequent steps can be down directly on the source excel file

# %%
cleanedList = [x for x in set(model_def["English"].to_list()) if str(x) != 'nan']
cleanedList = list(cleanedList)
flat_model = model_def.loc[model_def["English"].isin(cleanedList)]
property_model = flat_model[["Deutsch", "English", "français", "Required : Y/N", "Repeated : Y/N", "Data type",  "Description - see document \"Data model - minimum set of fields: definitions\""]]
property_model.drop_duplicates()

wikibase_prop_model = property_model[["Deutsch", "English", "français", "Data type", "Description - see document \"Data model - minimum set of fields: definitions\""]].drop_duplicates()
wikibase_prop_model.sort_values(by=['English'])

# %% [markdown]
# ## Create properties

# %%
property_model["English"].unique()
for index, row in wikibase_prop_model.iterrows():
    if row["Data type"] in datatype_map.values():
        try: 
            print(row["English"])
            createProperty(login, enlabel=row["English"], frlabel=row["français"], delabel=row["Deutsch"], description="Lux SAF Property", property_datatype=row["Data type"])
        except:
            print("tjope")

# %% [markdown]
# # Create Numerals

# %%
from collections import OrderedDict

def write_roman(num):

    roman = OrderedDict()
    roman[1000] = "M"
    roman[900] = "CM"
    roman[500] = "D"
    roman[400] = "CD"
    roman[100] = "C"
    roman[90] = "XC"
    roman[50] = "L"
    roman[40] = "XL"
    roman[10] = "X"
    roman[9] = "IX"
    roman[5] = "V"
    roman[4] = "IV"
    roman[1] = "I"

    def roman_num(num):
        for r in roman.keys():
            x, y = divmod(num, r)
            yield roman[r] * x
            num -= (r * x)
            if num <= 0:
                break

    return "".join([a for a in roman_num(num)])

# %%
write_roman(123)
# Out:
# 'CXXIII'

# %%
for i in range(2021):
    statements = []
    statements.append(wdi_core.WDItemID(value="Q338", prop_nr="P2"))
    numeration_item = wdi_core.WDItemEngine(new_item=True, data=statements, mediawiki_api_url=api, sparql_endpoint_url=sparql)
    numeration_item.set_label(write_roman(i), lang="en")
    numeration_item.set_label(write_roman(i), lang="fr")
    numeration_item.set_label(write_roman(i), lang="de")
    print(i, write_roman(i), numeration_item.write(login))
# Out:
# 0  Q339
# 1 I Q340
# 2 II Q341
# 3 III Q342
# 4 IV Q343
# 5 V Q344
# 6 VI Q345
# 7 VII Q346
# 8 VIII Q347
# 9 IX Q348
# 10 X Q349
# 11 XI Q350
# 12 XII Q351
# 13 XIII Q352
# 14 XIV Q353
# 15 XV Q354
# 16 XVI Q355
# 17 XVII Q356
# 18 XVIII Q357
# 19 XIX Q358
# 20 XX Q359
# 21 XXI Q360
# 22 XXII Q361
# 23 XXIII Q362
# 24 XXIV Q363
# 25 XXV Q364
# 26 XXVI Q365
# 27 XXVII Q366
# 28 XXVIII Q367
# 29 XXIX Q368
# 30 XXX Q369
# 31 XXXI Q370
# 32 XXXII Q371
# 33 XXXIII Q372
# 34 XXXIV Q373
# 35 XXXV Q374
# 36 XXXVI Q375
# 37 XXXVII Q376
# 38 XXXVIII Q377
# 39 XXXIX Q378
# 40 XL Q379
# 41 XLI Q380
# 42 XLII Q381
# 43 XLIII Q382
# 44 XLIV Q383
# 45 XLV Q384
# 46 XLVI Q385
# 47 XLVII Q386
# 48 XLVIII Q387
# 49 XLIX Q388
# 50 L Q389
# 51 LI Q390
# 52 LII Q391
# 53 LIII Q392
# 54 LIV Q393
# 55 LV Q394
# 56 LVI Q395
# 57 LVII Q396
# 58 LVIII Q397
# 59 LIX Q398
# 60 LX Q399
# 61 LXI Q400
# 62 LXII Q401
# 63 LXIII Q402
# 64 LXIV Q403
# 65 LXV Q404
# 66 LXVI Q405
# 67 LXVII Q406
# 68 LXVIII Q407
# 69 LXIX Q408
# 70 LXX Q409
# 71 LXXI Q410
# 72 LXXII Q411
# 73 LXXIII Q412
# 74 LXXIV Q413
# 75 LXXV Q414
# 76 LXXVI Q415
# 77 LXXVII Q416
# 78 LXXVIII Q417
# 79 LXXIX Q418
# 80 LXXX Q419
# 81 LXXXI Q420
# 82 LXXXII Q421
# 83 LXXXIII Q422
# 84 LXXXIV Q423
# 85 LXXXV Q424
# 86 LXXXVI Q425
# 87 LXXXVII Q426
# 88 LXXXVIII Q427
# 89 LXXXIX Q428
# 90 XC Q429
# 91 XCI Q430
# 92 XCII Q431
# 93 XCIII Q432
# 94 XCIV Q433
# 95 XCV Q434
# 96 XCVI Q435
# 97 XCVII Q436
# 98 XCVIII Q437
# 99 XCIX Q438
# 100 C Q439
# 101 CI Q440
# 102 CII Q441
# 103 CIII Q442
# 104 CIV Q443
# 105 CV Q444
# 106 CVI Q445
# 107 CVII Q446
# 108 CVIII Q447
# 109 CIX Q448
# 110 CX Q449
# 111 CXI Q450
# 112 CXII Q451
# 113 CXIII Q452
# 114 CXIV Q453
# 115 CXV Q454
# 116 CXVI Q455
# 117 CXVII Q456
# 118 CXVIII Q457
# 119 CXIX Q458
# 120 CXX Q459
# 121 CXXI Q460
# 122 CXXII Q461
# 123 CXXIII Q462
# 124 CXXIV Q463
# 125 CXXV Q464
# 126 CXXVI Q465
# 127 CXXVII Q466
# 128 CXXVIII Q467
# 129 CXXIX Q468
# 130 CXXX Q469
# 131 CXXXI Q470
# 132 CXXXII Q471
# 133 CXXXIII Q472
# 134 CXXXIV Q473
# 135 CXXXV Q474
# 136 CXXXVI Q475
# 137 CXXXVII Q476
# 138 CXXXVIII Q477
# 139 CXXXIX Q478
# 140 CXL Q479
# 141 CXLI Q480
# 142 CXLII Q481
# 143 CXLIII Q482
# 144 CXLIV Q483
# 145 CXLV Q484
# 146 CXLVI Q485
# 147 CXLVII Q486
# 148 CXLVIII Q487
# 149 CXLIX Q488
# 150 CL Q489
# 151 CLI Q490
# 152 CLII Q491
# 153 CLIII Q492
# 154 CLIV Q493
# 155 CLV Q494
# 156 CLVI Q495
# 157 CLVII Q496
# 158 CLVIII Q497
# 159 CLIX Q498
# 160 CLX Q499
# 161 CLXI Q500
# 162 CLXII Q501
# 163 CLXIII Q502
# 164 CLXIV Q503
# 165 CLXV Q504
# 166 CLXVI Q505
# 167 CLXVII Q506
# 168 CLXVIII Q507
# 169 CLXIX Q508
# 170 CLXX Q509
# 171 CLXXI Q510
# 172 CLXXII Q511
# 173 CLXXIII Q512
# 174 CLXXIV Q513
# 175 CLXXV Q514
# 176 CLXXVI Q515
# 177 CLXXVII Q516
# 178 CLXXVIII Q517
# 179 CLXXIX Q518
# 180 CLXXX Q519
# 181 CLXXXI Q520
# 182 CLXXXII Q521
# 183 CLXXXIII Q522
# 184 CLXXXIV Q523
# 185 CLXXXV Q524
# 186 CLXXXVI Q525
# 187 CLXXXVII Q526
# 188 CLXXXVIII Q527
# 189 CLXXXIX Q528
# 190 CXC Q529
# 191 CXCI Q530
# 192 CXCII Q531
# 193 CXCIII Q532
# 194 CXCIV Q533
# 195 CXCV Q534
# 196 CXCVI Q535
# 197 CXCVII Q536
# 198 CXCVIII Q537
# 199 CXCIX Q538
# 200 CC Q539
# 201 CCI Q540
# 202 CCII Q541
# 203 CCIII Q542
# 204 CCIV Q543
# 205 CCV Q544
# 206 CCVI Q545
# 207 CCVII Q546
# 208 CCVIII Q547
# 209 CCIX Q548
# 210 CCX Q549
# 211 CCXI Q550
# 212 CCXII Q551
# 213 CCXIII Q552
# 214 CCXIV Q553
# 215 CCXV Q554
# 216 CCXVI Q555
# 217 CCXVII Q556
# 218 CCXVIII Q557
# 219 CCXIX Q558
# 220 CCXX Q559
# 221 CCXXI Q560
# 222 CCXXII Q561
# 223 CCXXIII Q562
# 224 CCXXIV Q563
# 225 CCXXV Q564
# 226 CCXXVI Q565
# 227 CCXXVII Q566
# 228 CCXXVIII Q567
# 229 CCXXIX Q568
# 230 CCXXX Q569
# 231 CCXXXI Q570
# 232 CCXXXII Q571
# 233 CCXXXIII Q572
# 234 CCXXXIV Q573
# 235 CCXXXV Q574
# 236 CCXXXVI Q575
# 237 CCXXXVII Q576
# 238 CCXXXVIII Q577
# 239 CCXXXIX Q578
# 240 CCXL Q579
# 241 CCXLI Q580
# 242 CCXLII Q581
# 243 CCXLIII Q582
# 244 CCXLIV Q583
# 245 CCXLV Q584
# 246 CCXLVI Q585
# 247 CCXLVII Q586
# 248 CCXLVIII Q587
# 249 CCXLIX Q588
# 250 CCL Q589
# 251 CCLI Q590
# 252 CCLII Q591
# 253 CCLIII Q592
# 254 CCLIV Q593
# 255 CCLV Q594
# 256 CCLVI Q595
# 257 CCLVII Q596
# 258 CCLVIII Q597
# 259 CCLIX Q598
# 260 CCLX Q599
# 261 CCLXI Q600
# 262 CCLXII Q601
# 263 CCLXIII Q602
# 264 CCLXIV Q603
# 265 CCLXV Q604
# 266 CCLXVI Q605
# 267 CCLXVII Q606
# 268 CCLXVIII Q607
# 269 CCLXIX Q608
# 270 CCLXX Q609
# 271 CCLXXI Q610
# 272 CCLXXII Q611
# 273 CCLXXIII Q612
# 274 CCLXXIV Q613
# 275 CCLXXV Q614
# 276 CCLXXVI Q615
# 277 CCLXXVII Q616
# 278 CCLXXVIII Q617
# 279 CCLXXIX Q618
# 280 CCLXXX Q619
# 281 CCLXXXI Q620
# 282 CCLXXXII Q621
# 283 CCLXXXIII Q622
# 284 CCLXXXIV Q623
# 285 CCLXXXV Q624
# 286 CCLXXXVI Q625
# 287 CCLXXXVII Q626
# 288 CCLXXXVIII Q627
# 289 CCLXXXIX Q628
# 290 CCXC Q629
# 291 CCXCI Q630
# 292 CCXCII Q631
# 293 CCXCIII Q632
# 294 CCXCIV Q633
# 295 CCXCV Q634
# 296 CCXCVI Q635
# 297 CCXCVII Q636
# 298 CCXCVIII Q637
# 299 CCXCIX Q638
# 300 CCC Q639
# 301 CCCI Q640
# 302 CCCII Q641
# 303 CCCIII Q642
# 304 CCCIV Q643
# 305 CCCV Q644
# 306 CCCVI Q645
# 307 CCCVII Q646
# 308 CCCVIII Q647
# 309 CCCIX Q648
# 310 CCCX Q649
# 311 CCCXI Q650
# 312 CCCXII Q651
# 313 CCCXIII Q652
# 314 CCCXIV Q653
# 315 CCCXV Q654
# 316 CCCXVI Q655
# 317 CCCXVII Q656
# 318 CCCXVIII Q657
# 319 CCCXIX Q658
# 320 CCCXX Q659
# 321 CCCXXI Q660
# 322 CCCXXII Q661
# 323 CCCXXIII Q662
# 324 CCCXXIV Q663
# 325 CCCXXV Q664
# 326 CCCXXVI Q665
# 327 CCCXXVII Q666
# 328 CCCXXVIII Q667
# 329 CCCXXIX Q668
# 330 CCCXXX Q669
# 331 CCCXXXI Q670
# 332 CCCXXXII Q671
# 333 CCCXXXIII Q672
# 334 CCCXXXIV Q673
# 335 CCCXXXV Q674
# 336 CCCXXXVI Q675
# 337 CCCXXXVII Q676
# 338 CCCXXXVIII Q677
# 339 CCCXXXIX Q678
# 340 CCCXL Q679
# 341 CCCXLI Q680
# 342 CCCXLII Q681
# 343 CCCXLIII Q682
# 344 CCCXLIV Q683
# 345 CCCXLV Q684
# 346 CCCXLVI Q685
# 347 CCCXLVII Q686
# 348 CCCXLVIII Q687
# 349 CCCXLIX Q688
# 350 CCCL Q689
# 351 CCCLI Q690
# 352 CCCLII Q691
# 353 CCCLIII Q692
# 354 CCCLIV Q693
# 355 CCCLV Q694
# 356 CCCLVI Q695
# 357 CCCLVII Q696
# 358 CCCLVIII Q697
# 359 CCCLIX Q698
# 360 CCCLX Q699
# 361 CCCLXI Q700
# 362 CCCLXII Q701
# 363 CCCLXIII Q702
# 364 CCCLXIV Q703
# 365 CCCLXV Q704
# 366 CCCLXVI Q705
# 367 CCCLXVII Q706
# 368 CCCLXVIII Q707
# 369 CCCLXIX Q708
# 370 CCCLXX Q709
# 371 CCCLXXI Q710
# 372 CCCLXXII Q711
# 373 CCCLXXIII Q712
# 374 CCCLXXIV Q713
# 375 CCCLXXV Q714
# 376 CCCLXXVI Q715
# 377 CCCLXXVII Q716
# 378 CCCLXXVIII Q717
# 379 CCCLXXIX Q718
# 380 CCCLXXX Q719
# 381 CCCLXXXI Q720
# 382 CCCLXXXII Q721
# 383 CCCLXXXIII Q722
# 384 CCCLXXXIV Q723
# 385 CCCLXXXV Q724
# 386 CCCLXXXVI Q725
# 387 CCCLXXXVII Q726
# 388 CCCLXXXVIII Q727
# 389 CCCLXXXIX Q728
# 390 CCCXC Q729
# 391 CCCXCI Q730
# 392 CCCXCII Q731
# 393 CCCXCIII Q732
# 394 CCCXCIV Q733
# 395 CCCXCV Q734
# 396 CCCXCVI Q735
# 397 CCCXCVII Q736
# 398 CCCXCVIII Q737
# 399 CCCXCIX Q738
# 400 CD Q739
# 401 CDI Q740
# 402 CDII Q741
# 403 CDIII Q742
# 404 CDIV Q743
# 405 CDV Q744
# 406 CDVI Q745
# 407 CDVII Q746
# 408 CDVIII Q747
# 409 CDIX Q748
# 410 CDX Q749
# 411 CDXI Q750
# 412 CDXII Q751
# 413 CDXIII Q752
# 414 CDXIV Q753
# 415 CDXV Q754
# 416 CDXVI Q755
# 417 CDXVII Q756
# 418 CDXVIII Q757
# 419 CDXIX Q758
# 420 CDXX Q759
# 421 CDXXI Q760
# 422 CDXXII Q761
# 423 CDXXIII Q762
# 424 CDXXIV Q763
# 425 CDXXV Q764
# 426 CDXXVI Q765
# 427 CDXXVII Q766
# 428 CDXXVIII Q767
# 429 CDXXIX Q768
# 430 CDXXX Q769
# 431 CDXXXI Q770
# 432 CDXXXII Q771
# 433 CDXXXIII Q772
# 434 CDXXXIV Q773
# 435 CDXXXV Q774
# 436 CDXXXVI Q775
# 437 CDXXXVII Q776
# 438 CDXXXVIII Q777
# 439 CDXXXIX Q778
# 440 CDXL Q779
# 441 CDXLI Q780
# 442 CDXLII Q781
# 443 CDXLIII Q782
# 444 CDXLIV Q783
# 445 CDXLV Q784
# 446 CDXLVI Q785
# 447 CDXLVII Q786
# 448 CDXLVIII Q787
# 449 CDXLIX Q788
# 450 CDL Q789
# 451 CDLI Q790
# 452 CDLII Q791
# 453 CDLIII Q792
# 454 CDLIV Q793
# 455 CDLV Q794
# 456 CDLVI Q795
# 457 CDLVII Q796
# 458 CDLVIII Q797
# 459 CDLIX Q798
# 460 CDLX Q799
# 461 CDLXI Q800
# 462 CDLXII Q801
# 463 CDLXIII Q802
# 464 CDLXIV Q803
# 465 CDLXV Q804
# 466 CDLXVI Q805
# 467 CDLXVII Q806
# 468 CDLXVIII Q807
# 469 CDLXIX Q808
# 470 CDLXX Q809
# 471 CDLXXI Q810
# 472 CDLXXII Q811
# 473 CDLXXIII Q812
# 474 CDLXXIV Q813
# 475 CDLXXV Q814
# 476 CDLXXVI Q815
# 477 CDLXXVII Q816
# 478 CDLXXVIII Q817
# 479 CDLXXIX Q818
# 480 CDLXXX Q819
# 481 CDLXXXI Q820
# 482 CDLXXXII Q821
# 483 CDLXXXIII Q822
# 484 CDLXXXIV Q823
# 485 CDLXXXV Q824
# 486 CDLXXXVI Q825
# 487 CDLXXXVII Q826
# 488 CDLXXXVIII Q827
# 489 CDLXXXIX Q828
# 490 CDXC Q829
# 491 CDXCI Q830
# 492 CDXCII Q831
# 493 CDXCIII Q832
# 494 CDXCIV Q833
# 495 CDXCV Q834
# 496 CDXCVI Q835
# 497 CDXCVII Q836
# 498 CDXCVIII Q837
# 499 CDXCIX Q838
# 500 D Q839
# 501 DI Q840
# 502 DII Q841
# 503 DIII Q842
# 504 DIV Q843
# 505 DV Q844
# 506 DVI Q845
# 507 DVII Q846
# 508 DVIII Q847
# 509 DIX Q848
# 510 DX Q849
# 511 DXI Q850
# 512 DXII Q851
# 513 DXIII Q852
# 514 DXIV Q853
# 515 DXV Q854
# 516 DXVI Q855
# 517 DXVII Q856
# 518 DXVIII Q857
# 519 DXIX Q858
# 520 DXX Q859
# 521 DXXI Q860
# 522 DXXII Q861
# 523 DXXIII Q862
# 524 DXXIV Q863
# 525 DXXV Q864
# 526 DXXVI Q865
# 527 DXXVII Q866
# 528 DXXVIII Q867
# 529 DXXIX Q868
# 530 DXXX Q869
# 531 DXXXI Q870
# 532 DXXXII Q871
# 533 DXXXIII Q872
# 534 DXXXIV Q873
# 535 DXXXV Q874
# 536 DXXXVI Q875
# 537 DXXXVII Q876
# 538 DXXXVIII Q877
# 539 DXXXIX Q878
# 540 DXL Q879
# 541 DXLI Q880
# 542 DXLII Q881
# 543 DXLIII Q882
# 544 DXLIV Q883
# 545 DXLV Q884
# 546 DXLVI Q885
# 547 DXLVII Q886
# 548 DXLVIII Q887
# 549 DXLIX Q888
# 550 DL Q889
# 551 DLI Q890
# 552 DLII Q891
# 553 DLIII Q892
# 554 DLIV Q893
# 555 DLV Q894
# 556 DLVI Q895
# 557 DLVII Q896
# 558 DLVIII Q897
# 559 DLIX Q898
# 560 DLX Q899
# 561 DLXI Q900
# 562 DLXII Q901
# 563 DLXIII Q902
# 564 DLXIV Q903
# 565 DLXV Q904
# 566 DLXVI Q905
# 567 DLXVII Q906
# 568 DLXVIII Q907
# 569 DLXIX Q908
# 570 DLXX Q909
# 571 DLXXI Q910
# 572 DLXXII Q911
# 573 DLXXIII Q912
# 574 DLXXIV Q913
# 575 DLXXV Q914
# 576 DLXXVI Q915
# 577 DLXXVII Q916
# 578 DLXXVIII Q917
# 579 DLXXIX Q918
# 580 DLXXX Q919
# 581 DLXXXI Q920
# 582 DLXXXII Q921
# 583 DLXXXIII Q922
# 584 DLXXXIV Q923
# 585 DLXXXV Q924
# 586 DLXXXVI Q925
# 587 DLXXXVII Q926
# 588 DLXXXVIII Q927
# 589 DLXXXIX Q928
# 590 DXC Q929
# 591 DXCI Q930
# 592 DXCII Q931
# 593 DXCIII Q932
# 594 DXCIV Q933
# 595 DXCV Q934
# 596 DXCVI Q935
# 597 DXCVII Q936
# 598 DXCVIII Q937
# 599 DXCIX Q938
# 600 DC Q939
# 601 DCI Q940
# 602 DCII Q941
# 603 DCIII Q942
# 604 DCIV Q943
# 605 DCV Q944
# 606 DCVI Q945
# 607 DCVII Q946
# 608 DCVIII Q947
# 609 DCIX Q948
# 610 DCX Q949
# 611 DCXI Q950
# 612 DCXII Q951
# 613 DCXIII Q952
# 614 DCXIV Q953
# 615 DCXV Q954
# 616 DCXVI Q955
# 617 DCXVII Q956
# 618 DCXVIII Q957
# 619 DCXIX Q958
# 620 DCXX Q959
# 621 DCXXI Q960
# 622 DCXXII Q961
# 623 DCXXIII Q962
# 624 DCXXIV Q963
# 625 DCXXV Q964
# 626 DCXXVI Q965
# 627 DCXXVII Q966
# 628 DCXXVIII Q967
# 629 DCXXIX Q968
# 630 DCXXX Q969
# 631 DCXXXI Q970
# 632 DCXXXII Q971
# 633 DCXXXIII Q972
# 634 DCXXXIV Q973
# 635 DCXXXV Q974
# 636 DCXXXVI Q975
# 637 DCXXXVII Q976
# 638 DCXXXVIII Q977
# 639 DCXXXIX Q978
# 640 DCXL Q979
# 641 DCXLI Q980
# 642 DCXLII Q981
# 643 DCXLIII Q982
# 644 DCXLIV Q983
# 645 DCXLV Q984
# 646 DCXLVI Q985
# 647 DCXLVII Q986
# 648 DCXLVIII Q987
# 649 DCXLIX Q988
# 650 DCL Q989
# 651 DCLI Q990
# 652 DCLII Q991
# 653 DCLIII Q992
# 654 DCLIV Q993
# 655 DCLV Q994
# 656 DCLVI Q995
# 657 DCLVII Q996
# 658 DCLVIII Q997
# 659 DCLIX Q998
# 660 DCLX Q999
# 661 DCLXI Q1000
# 662 DCLXII Q1001
# 663 DCLXIII Q1002
# 664 DCLXIV Q1003
# 665 DCLXV Q1004
# 666 DCLXVI Q1005
# 667 DCLXVII Q1006
# 668 DCLXVIII Q1007
# 669 DCLXIX Q1008
# 670 DCLXX Q1009
# 671 DCLXXI Q1010
# 672 DCLXXII Q1011
# 673 DCLXXIII Q1012
# 674 DCLXXIV Q1013
# 675 DCLXXV Q1014
# 676 DCLXXVI Q1015
# 677 DCLXXVII Q1016
# 678 DCLXXVIII Q1017
# 679 DCLXXIX Q1018
# 680 DCLXXX Q1019
# 681 DCLXXXI Q1020
# 682 DCLXXXII Q1021
# 683 DCLXXXIII Q1022
# 684 DCLXXXIV Q1023
# 685 DCLXXXV Q1024
# 686 DCLXXXVI Q1025
# 687 DCLXXXVII Q1026
# 688 DCLXXXVIII Q1027
# 689 DCLXXXIX Q1028
# 690 DCXC Q1029
# 691 DCXCI Q1030
# 692 DCXCII Q1031
# 693 DCXCIII Q1032
# 694 DCXCIV Q1033
# 695 DCXCV Q1034
# 696 DCXCVI Q1035
# 697 DCXCVII Q1036
# 698 DCXCVIII Q1037
# 699 DCXCIX Q1038
# 700 DCC Q1039
# 701 DCCI Q1040
# 702 DCCII Q1041
# 703 DCCIII Q1042
# 704 DCCIV Q1043
# 705 DCCV Q1044
# 706 DCCVI Q1045
# 707 DCCVII Q1046
# 708 DCCVIII Q1047
# 709 DCCIX Q1048
# 710 DCCX Q1049
# 711 DCCXI Q1050
# 712 DCCXII Q1051
# 713 DCCXIII Q1052
# 714 DCCXIV Q1053
# 715 DCCXV Q1054
# 716 DCCXVI Q1055
# 717 DCCXVII Q1056
# 718 DCCXVIII Q1057
# 719 DCCXIX Q1058
# 720 DCCXX Q1059
# 721 DCCXXI Q1060
# 722 DCCXXII Q1061
# 723 DCCXXIII Q1062
# 724 DCCXXIV Q1063
# 725 DCCXXV Q1064
# 726 DCCXXVI Q1065
# 727 DCCXXVII Q1066
# 728 DCCXXVIII Q1067
# 729 DCCXXIX Q1068
# 730 DCCXXX Q1069
# 731 DCCXXXI Q1070
# 732 DCCXXXII Q1071
# 733 DCCXXXIII Q1072
# 734 DCCXXXIV Q1073
# 735 DCCXXXV Q1074
# 736 DCCXXXVI Q1075
# 737 DCCXXXVII Q1076
# 738 DCCXXXVIII Q1077
# 739 DCCXXXIX Q1078
# 740 DCCXL Q1079
# 741 DCCXLI Q1080
# 742 DCCXLII Q1081
# 743 DCCXLIII Q1082
# 744 DCCXLIV Q1083
# 745 DCCXLV Q1084
# 746 DCCXLVI Q1085
# 747 DCCXLVII Q1086
# 748 DCCXLVIII Q1087
# 749 DCCXLIX Q1088
# 750 DCCL Q1089
# 751 DCCLI Q1090
# 752 DCCLII Q1091
# 753 DCCLIII Q1092
# 754 DCCLIV Q1093
# 755 DCCLV Q1094
# 756 DCCLVI Q1095
# 757 DCCLVII Q1096
# 758 DCCLVIII Q1097
# 759 DCCLIX Q1098
# 760 DCCLX Q1099
# 761 DCCLXI Q1100
# 762 DCCLXII Q1101
# 763 DCCLXIII Q1102
# 764 DCCLXIV Q1103
# 765 DCCLXV Q1104
# 766 DCCLXVI Q1105
# 767 DCCLXVII Q1106
# 768 DCCLXVIII Q1107
# 769 DCCLXIX Q1108
# 770 DCCLXX Q1109
# 771 DCCLXXI Q1110
# 772 DCCLXXII Q1111
# 773 DCCLXXIII Q1112
# 774 DCCLXXIV Q1113
# 775 DCCLXXV Q1114
# 776 DCCLXXVI Q1115
# 777 DCCLXXVII Q1116
# 778 DCCLXXVIII Q1117
# 779 DCCLXXIX Q1118
# 780 DCCLXXX Q1119
# 781 DCCLXXXI Q1120
# 782 DCCLXXXII Q1121
# 783 DCCLXXXIII Q1122
# 784 DCCLXXXIV Q1123
# 785 DCCLXXXV Q1124
# 786 DCCLXXXVI Q1125
# 787 DCCLXXXVII Q1126
# 788 DCCLXXXVIII Q1127
# 789 DCCLXXXIX Q1128
# 790 DCCXC Q1129
# 791 DCCXCI Q1130
# 792 DCCXCII Q1131
# 793 DCCXCIII Q1132
# 794 DCCXCIV Q1133
# 795 DCCXCV Q1134
# 796 DCCXCVI Q1135
# 797 DCCXCVII Q1136
# 798 DCCXCVIII Q1137
# 799 DCCXCIX Q1138
# 800 DCCC Q1139
# 801 DCCCI Q1140
# 802 DCCCII Q1141
# 803 DCCCIII Q1142
# 804 DCCCIV Q1143
# 805 DCCCV Q1144
# 806 DCCCVI Q1145
# 807 DCCCVII Q1146
# 808 DCCCVIII Q1147
# 809 DCCCIX Q1148
# 810 DCCCX Q1149
# 811 DCCCXI Q1150
# 812 DCCCXII Q1151
# 813 DCCCXIII Q1152
# 814 DCCCXIV Q1153
# 815 DCCCXV Q1154
# 816 DCCCXVI Q1155
# 817 DCCCXVII Q1156
# 818 DCCCXVIII Q1157
# 819 DCCCXIX Q1158
# 820 DCCCXX Q1159
# 821 DCCCXXI Q1160
# 822 DCCCXXII Q1161
# 823 DCCCXXIII Q1162
# 824 DCCCXXIV Q1163
# 825 DCCCXXV Q1164
# 826 DCCCXXVI Q1165
# 827 DCCCXXVII Q1166
# 828 DCCCXXVIII Q1167
# 829 DCCCXXIX Q1168
# 830 DCCCXXX Q1169
# 831 DCCCXXXI Q1170
# 832 DCCCXXXII Q1171
# 833 DCCCXXXIII Q1172
# 834 DCCCXXXIV Q1173
# 835 DCCCXXXV Q1174
# 836 DCCCXXXVI Q1175
# 837 DCCCXXXVII Q1176
# 838 DCCCXXXVIII Q1177
# 839 DCCCXXXIX Q1178
# 840 DCCCXL Q1179
# 841 DCCCXLI Q1180
# 842 DCCCXLII Q1181
# 843 DCCCXLIII Q1182
# 844 DCCCXLIV Q1183
# 845 DCCCXLV Q1184
# 846 DCCCXLVI Q1185
# 847 DCCCXLVII Q1186
# 848 DCCCXLVIII Q1187
# 849 DCCCXLIX Q1188
# 850 DCCCL Q1189
# 851 DCCCLI Q1190
# 852 DCCCLII Q1191
# 853 DCCCLIII Q1192
# 854 DCCCLIV Q1193
# 855 DCCCLV Q1194
# 856 DCCCLVI Q1195
# 857 DCCCLVII Q1196
# 858 DCCCLVIII Q1197
# 859 DCCCLIX Q1198
# 860 DCCCLX Q1199
# 861 DCCCLXI Q1200
# 862 DCCCLXII Q1201
# 863 DCCCLXIII Q1202
# 864 DCCCLXIV Q1203
# 865 DCCCLXV Q1204
# 866 DCCCLXVI Q1205
# 867 DCCCLXVII Q1206
# 868 DCCCLXVIII Q1207
# 869 DCCCLXIX Q1208
# 870 DCCCLXX Q1209
# 871 DCCCLXXI Q1210
# 872 DCCCLXXII Q1211
# 873 DCCCLXXIII Q1212
# 874 DCCCLXXIV Q1213
# 875 DCCCLXXV Q1214
# 876 DCCCLXXVI Q1215
# 877 DCCCLXXVII Q1216
# 878 DCCCLXXVIII Q1217
# 879 DCCCLXXIX Q1218
# 880 DCCCLXXX Q1219
# 881 DCCCLXXXI Q1220
# 882 DCCCLXXXII Q1221
# 883 DCCCLXXXIII Q1222
# 884 DCCCLXXXIV Q1223
# 885 DCCCLXXXV Q1224
# 886 DCCCLXXXVI Q1225
# 887 DCCCLXXXVII Q1226
# 888 DCCCLXXXVIII Q1227
# 889 DCCCLXXXIX Q1228
# 890 DCCCXC Q1229
# 891 DCCCXCI Q1230
# 892 DCCCXCII Q1231
# 893 DCCCXCIII Q1232
# 894 DCCCXCIV Q1233
# 895 DCCCXCV Q1234
# 896 DCCCXCVI Q1235
# 897 DCCCXCVII Q1236
# 898 DCCCXCVIII Q1237
# 899 DCCCXCIX Q1238
# 900 CM Q1239
# 901 CMI Q1240
# 902 CMII Q1241
# 903 CMIII Q1242
# 904 CMIV Q1243
# 905 CMV Q1244
# 906 CMVI Q1245
# 907 CMVII Q1246
# 908 CMVIII Q1247
# 909 CMIX Q1248
# 910 CMX Q1249
# 911 CMXI Q1250
# 912 CMXII Q1251
# 913 CMXIII Q1252
# 914 CMXIV Q1253
# 915 CMXV Q1254
# 916 CMXVI Q1255
# 917 CMXVII Q1256
# 918 CMXVIII Q1257
# 919 CMXIX Q1258
# 920 CMXX Q1259
# 921 CMXXI Q1260
# 922 CMXXII Q1261
# 923 CMXXIII Q1262
# 924 CMXXIV Q1263
# 925 CMXXV Q1264
# 926 CMXXVI Q1265
# 927 CMXXVII Q1266
# 928 CMXXVIII Q1267
# 929 CMXXIX Q1268
# 930 CMXXX Q1269
# 931 CMXXXI Q1270
# 932 CMXXXII Q1271
# 933 CMXXXIII Q1272
# 934 CMXXXIV Q1273
# 935 CMXXXV Q1274
# 936 CMXXXVI Q1275
# 937 CMXXXVII Q1276
# 938 CMXXXVIII Q1277
# 939 CMXXXIX Q1278
# 940 CMXL Q1279
# 941 CMXLI Q1280
# 942 CMXLII Q1281
# 943 CMXLIII Q1282
# 944 CMXLIV Q1283
# 945 CMXLV Q1284
# 946 CMXLVI Q1285
# 947 CMXLVII Q1286
# 948 CMXLVIII Q1287
# 949 CMXLIX Q1288
# 950 CML Q1289
# 951 CMLI Q1290
# 952 CMLII Q1291
# 953 CMLIII Q1292
# 954 CMLIV Q1293
# 955 CMLV Q1294
# 956 CMLVI Q1295
# 957 CMLVII Q1296
# 958 CMLVIII Q1297
# 959 CMLIX Q1298

# %%
dir(login)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'callback_url',
#  'consumer_key',
#  'consumer_secret',
#  'continue_oauth',
#  'edit_token',
#  'generate_edit_credentials',
#  'generate_rollback_credentials',
#  'get_edit_cookie',
#  'get_edit_token',
#  'get_rollback_token',
#  'get_session',
#  'instantiation_time',
#  'mediawiki_api_url',
#  'mediawiki_index_url',
#  'response_qs',
#  'rollback_token',
#  's',
#  'token_renew_period',
#  'user',
#  'user_agent']

# %%
login.get_edit_token()
# Out:
# 'a719e5c3d294d6d8f2666d531da3532f60a6c77f+\\'

# %%
login.get_rollback_token()
# Out:
# '7ece8e53c287be4f7d3730a1a985391160a6c9d8+\\'
