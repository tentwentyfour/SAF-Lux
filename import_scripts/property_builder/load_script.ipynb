# %% [markdown]
# # load necessary libraries

# %%
import pandas as pd

# %% [markdown]
# # Load data

# %%
pd.read_excel("20210315-initial export anlux-jt.xlsx")
# Out:
#                                           Heading:Name  Heading:Type  \
# 0                                   Aa, Petrus van der             1
# 1                                      Abraham d'Orval             1
# 2                                     Adami, Guillaume             1
# 3                               Agarant, Clément, s.j.             1
# 4                                     Alberti, Nicolas             1
# ..                                                 ...           ...
# 528                                Zelle, Louis Joseph             1
# 529                  Zender, Benoît, abbé d'Echternach             1
# 530  Zievel, Jean Henri de, baron, seigneur de Bett...             1
# 531                                      Zorn, Jean de             1
# 532                                        Zorn, Marie             1
#
#      Heading:Numeration  Heading:Title  \
# 0                   NaN            NaN
# 1                   NaN            NaN
# ...
