# %% [markdown]
# # load necessary libraries

# %%
import pandas as pd

# %% [markdown]
# # Load data

# %%
#pd.read_excel("20210315-initial export anlux-jt.xlsx")
pd.read_excel("DM_SAF_vers.1.1.xlsx")
# Out:
#                                Unnamed: 0  \
# 0                                     NaN
# 1                                     NaN
# 2                                 Heading
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10    Alternative / other form(s) of name
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20  Associated identification information
# ...
