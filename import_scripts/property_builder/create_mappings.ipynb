# %%
from wikidataintegrator import wdi_core, wdi_login, wdi_config
from getpass import getpass
import pandas as pd

wbstack = "lux-saf-beta"
wikibase = "https://{}.wiki.opencura.com/".format(wbstack)
api = "https://{}.wiki.opencura.com/w/api.php".format(wbstack)
sparql = "https://{}.wiki.opencura.com/query/sparql".format(wbstack)
entityUri = wikibase.replace("https:", "http:")+"entity/"

WBUSER = "Andrawaag"
WBPASS = getpass()
login = wdi_login.WDLogin(WBUSER, WBPASS, mediawiki_api_url=api)
localEntityEngine = wdi_core.WDItemEngine.wikibase_item_engine_factory(api,sparql)
# Out:
# ········
# Successfully logged in as Andrawaag

# %%
df = pd.read_excel("../DM_SAF/DM_SAF_vers.1.0.2_andra.xlsx", sheet_name="CIDOC", header=2)

# %%
df2 = df[~df["English"].isnull()]

# %%
qid = dict()
query = "PREFIX wdt: <http://{}.wiki.opencura.com/prop/direct/> SELECT ?item ?label WHERE {{?item rdfs:label ?label }}".format(wbstack)
wdi_core.WDItemEngine.execute_sparql_query(query, as_dataframe = True, endpoint=sparql)
for index, row in wdi_core.WDItemEngine.execute_sparql_query(query, as_dataframe = True, endpoint=sparql).iterrows():
    qid[row["label"]] =row["item"].replace(entityUri, "")

# %%
df2
# Out:
#      Unnamed: 0 Unnamed: 1                    Field - AF  \
# 2           NaN        NaN                           NaN
# 3           NaN        NaN                          Type
# 5           NaN        NaN                           NaN
# 7           NaN        NaN                           NaN
# 9           NaN        NaN  Source of information - text
# ..          ...        ...                           ...
# 99          NaN        NaN                           NaN
# 101         NaN        NaN                           NaN
# 103         NaN        NaN                           NaN
# 104         NaN        NaN        Author of modification
# 105         NaN        NaN                Status of data
#
#                          Domain                               Property  \
# 2               E41 Appellation                         R8 consists of
# 3           E90 Symbolic Object                            P2 has type
# 5               E41 Appellation                         R8 consists of
# 7               E41 Appellation                         R8 consists of
# 9               E41 Appellation                  P70i is documented in
# ..                          ...                                    ...
# 99                    E39 Actor  P107 has current or former member of
# 101               E65 Creation                        P4 has time-span
# 103  E13 Attribute assignement                        P4 has time-span
# 104  E13 Attribute assignement                      P14 carried out by
# 105    E89 Propositional Object                            P2 has type
#
#                    Range                                         Definition  \
# 2    E90 Symbolic Object  This class comprises identifiable symbols and ...
# 3               E55 Type  This class comprises concepts denoted by terms...
# 5    E90 Symbolic Object  This class comprises identifiable symbols and ...
# 7    E90 Symbolic Object  This class comprises identifiable symbols and ...
# 9           E31 Document  This class comprises identifiable immaterial i...
# ..                   ...                                                ...
# 99            E74 Group   This class comprises any gatherings or organiz...
# 101        E52 Time-Span  This class comprises abstract temporal extents...
# 103        E52 Time-Span  This class comprises abstract temporal extents...
# 104            E39 Actor  This class comprises people, either individual...
# 105             E55 Type  This class comprises concepts denoted by terms...
#
#     Required : Y/N Repeated : Y/N               Data type  ...  \
# 2                Y              N                  string  ...
# 3                Y              N                  string  ...
# 5                N              N                 string   ...
# 7                N              N                 string   ...
# 9                Y              Y                  string  ...
# ..             ...            ...                     ...  ...
# 99               Y              Y                  string  ...
# 101              Y              N   \ncoded / date time\n  ...
# 103              Y              Y   \ncoded / date time\n  ...
# 104              Y              Y                 string   ...
# 105              Y              N                 string   ...
#
#          Public display         Example 1                      Example 2  \
# 2    < forname surname>        Cloos, Boy                      Charlotte
# 3                   NaN                 1                              0
# 5                   NaN               NaN                            NaN
# 7                   NaN               Jr.  Grande-Duchesse de Luxembourg
# 9                   NaN  lb.wikipedia.org          Site web monarchie.lu
# ..                  ...               ...                            ...
# 99                  NaN            LU-BNL                         LU-BNL
# 101                 NaN               NaN                            NaN
# 103                 NaN               NaN                            NaN
# 104                 NaN               NaN                            NaN
# 105                 NaN               NaN                            NaN
#
#                     Deutsch                    English  \
# 2                     Name                       name
# 3              Namensformat                name format
# 5               Numerierung                numeration
# 7                    Titel                      title
# 9                    Quelle      source of information
# ..                      ...                        ...
# 99   Institutszugehörgikeit  institutional affiliation
# 101        Erstellungsdatum           date of creation
# 103          Änderungsdatum       date of modification
# 104              Bearbeiter                     editor
# 105                  Status                    status
#
#                          français        Note Minimum set of fields   \
# 2                             nom           /                      Y
# 3                   format du nom  CL3 -final                      Y
# 5                    numérotation           /                      /
# 7                           titre           /                      /
# 9            source d'information           /                      Y
# ..                            ...         ...                    ...
# 99   affiliation institutionnelle           /                     YS
# 101              date de création           /                     YS
# 103          date de modification           /                     YS
# 104                        editor           /                     YS
# 105                        statut   CL5 final                     YS
#
#                                                  Notes Unnamed: 26
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 5                                                  NaN         NaN
# 7                                                  NaN         NaN
# 9      missing date of consultation for online sources         NaN
# ..                                                 ...         ...
# 99                                                 NaN         NaN
# 101  what about bulk uploads - there will exist an ...         NaN
# 103                                                NaN         NaN
# 104                                                NaN         NaN
# 105                                                NaN         NaN
#
# [70 rows x 27 columns]

# %%
import json
done = []
for index, row in df2.iterrows():
    if row["English"].strip() in qid.keys():
        try: 
            print(row["English"].strip(), "\t", qid[row["English"].strip()], qid[row["Range"].strip()], qid[row["Domain"].strip()], qid[row["Property"].strip()])
            statements = []
            statements.append(wdi_core.WDItemID(value=qid[row["Range"].strip()], prop_nr=qid["range"]))
            statements.append(wdi_core.WDItemID(value=qid[row["Domain"].strip()], prop_nr=qid["domain"]))
            statements.append(wdi_core.WDItemID(value=qid[row["Property"].strip()], prop_nr=qid["property"]))
            item = localEntityEngine(wd_item_id=qid[row["English"].strip()], data=statements)
            #print(json.dumps(item.get_wd_json_representation(), indent=4))
            item.write(login, entity_type="property")
        except Exception as e: 
            print("error", e)
            continue
# Out:
# name 	 P8 Q53 Q41 Q896
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "name"
#         },
#         "de": {
#             "language": "de",
#             "value": "Name"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "nom"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 41,
#                             "id": "Q41"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 53,
#                             "id": "Q53"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 896,
#                             "id": "Q896"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# name format 	 P9 Q70 Q53 Q158
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "name format"
#         },
#         "de": {
#             "language": "de",
#             "value": "Namensformat"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "format du nom"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 53,
#                             "id": "Q53"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 70,
#                             "id": "Q70"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 158,
#                             "id": "Q158"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# numeration 	 P10 Q53 Q41 Q896
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "numeration"
#         },
#         "de": {
#             "language": "de",
#             "value": "Numerierung"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "num\u00e9rotation"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 41,
#                             "id": "Q41"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 53,
#                             "id": "Q53"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 896,
#                             "id": "Q896"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# title 	 P11 Q53 Q41 Q896
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "title"
#         },
#         "de": {
#             "language": "de",
#             "value": "Titel"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "titre"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 41,
#                             "id": "Q41"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 53,
#                             "id": "Q53"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 896,
#                             "id": "Q896"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# type of source 	 P13 Q70 Q37 Q158
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "type of source"
#         },
#         "de": {
#             "language": "de",
#             "value": "Quellentyp"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "type de source d'information"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 37,
#                             "id": "Q37"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 70,
#                             "id": "Q70"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 158,
#                             "id": "Q158"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# alternative name 	 P17 Q53 Q41 Q896
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "alternative name"
#         },
#         "de": {
#             "language": "de",
#             "value": "Alternativname"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "nom alternatif"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 41,
#                             "id": "Q41"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 53,
#                             "id": "Q53"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 896,
#                             "id": "Q896"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# name format 	 P9 Q70 Q53 Q158
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "name format"
#         },
#         "de": {
#             "language": "de",
#             "value": "Namensformat"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "format du nom"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 53,
#                             "id": "Q53"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P9$D3CB0452-D8C3-43ED-9A72-DD45506373C3"
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 70,
#                             "id": "Q70"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P9$27E2A672-6C2B-4B33-B72F-1D12C25FA64B"
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 158,
#                             "id": "Q158"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P9$B0AD73A0-735A-4E8C-9210-0894FC879538"
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# numeration 	 P10 Q53 Q41 Q896
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "numeration"
#         },
#         "de": {
#             "language": "de",
#             "value": "Numerierung"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "num\u00e9rotation"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 41,
#                             "id": "Q41"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P10$E7C1F6A9-E33D-49A6-A584-F66CED51629A"
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 53,
#                             "id": "Q53"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P10$BCEF491B-C06E-4F08-A7B6-874AA9662AC0"
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 896,
#                             "id": "Q896"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P10$0506D803-47A2-4B45-B8DF-F0D5F285D60A"
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# title 	 P11 Q53 Q41 Q896
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "title"
#         },
#         "de": {
#             "language": "de",
#             "value": "Titel"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "titre"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 41,
#                             "id": "Q41"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P11$81C6E104-DB21-4339-AA2C-E59EDB196830"
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 53,
#                             "id": "Q53"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P11$C97C8EFD-B0EB-41B0-A035-0E9B9AE642EE"
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 896,
#                             "id": "Q896"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P11$2C106583-204C-48E6-BB06-C7B6B95B8861"
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# type of source 	 P13 Q70 Q37 Q158
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "type of source"
#         },
#         "de": {
#             "language": "de",
#             "value": "Quellentyp"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "type de source d'information"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 37,
#                             "id": "Q37"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P13$C8BC4C82-42B1-4B69-91C7-C3DF519F45D5"
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 70,
#                             "id": "Q70"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P13$5D44B420-A864-44DC-86EA-9BC8AFDC8ED1"
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 158,
#                             "id": "Q158"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P13$71E5A5EA-CDE2-4DDB-82BF-F1EEF00C941E"
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# date of birth 	 P18 Q21 Q42 Q106
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "date of birth"
#         },
#         "de": {
#             "language": "de",
#             "value": "Geburtsdatum"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "date de naissance"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 42,
#                             "id": "Q42"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 21,
#                             "id": "Q21"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 106,
#                             "id": "Q106"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# place of birth 	 P19 Q69 Q42 Q205
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "place of birth"
#         },
#         "de": {
#             "language": "de",
#             "value": "Geburtsort"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "lieu de naissance"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 42,
#                             "id": "Q42"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 69,
#                             "id": "Q69"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 205,
#                             "id": "Q205"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# type of source 	 P13 Q70 Q37 Q158
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "type of source"
#         },
#         "de": {
#             "language": "de",
#             "value": "Quellentyp"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "type de source d'information"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 37,
#                             "id": "Q37"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P13$C8BC4C82-42B1-4B69-91C7-C3DF519F45D5"
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 70,
#                             "id": "Q70"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P13$5D44B420-A864-44DC-86EA-9BC8AFDC8ED1"
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 158,
#                             "id": "Q158"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P13$71E5A5EA-CDE2-4DDB-82BF-F1EEF00C941E"
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# date of death 	 P20 Q21 Q66 Q106
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "date of death"
#         },
#         "de": {
#             "language": "de",
#             "value": "Sterbedatum"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "date de d\u00e9c\u00e8s"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 66,
#                             "id": "Q66"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 21,
#                             "id": "Q21"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 106,
#                             "id": "Q106"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# place of death 	 P21 Q69 Q66 Q205
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "place of death"
#         },
#         "de": {
#             "language": "de",
#             "value": "Sterbeort"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "lieu du d\u00e9c\u00e8s"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 66,
#                             "id": "Q66"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 69,
#                             "id": "Q69"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 205,
#                             "id": "Q205"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# type of source 	 P13 Q70 Q37 Q158
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "type of source"
#         },
#         "de": {
#             "language": "de",
#             "value": "Quellentyp"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "type de source d'information"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 37,
#                             "id": "Q37"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P13$C8BC4C82-42B1-4B69-91C7-C3DF519F45D5"
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 70,
#                             "id": "Q70"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P13$5D44B420-A864-44DC-86EA-9BC8AFDC8ED1"
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 158,
#                             "id": "Q158"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
#                 "id": "P13$71E5A5EA-CDE2-4DDB-82BF-F1EEF00C941E"
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# gender 	 P22 Q70 Q350 Q158
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "gender"
#         },
#         "de": {
#             "language": "de",
#             "value": "Geschlecht"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "sexe"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 350,
#                             "id": "Q350"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 70,
#                             "id": "Q70"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 158,
#                             "id": "Q158"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# type of source 	 P13 Q70 Q37 Q158
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "type of source"
#         },
#         "de": {
#             "language": "de",
#             "value": "Quellentyp"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "type de source d'information"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 37,
#                             "id": "Q37"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": [],
# ...
#             "language": "de",
#             "value": "Ersteller"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "cr\u00e9ateur"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 40,
#                             "id": "Q40"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 23,
#                             "id": "Q23"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 95,
#                             "id": "Q95"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# institutional affiliation 	 P31 Q84 Q23 Q900
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "institutional affiliation"
#         },
#         "de": {
#             "language": "de",
#             "value": "Institutszugeh\u00f6rgikeit"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "affiliation institutionnelle"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 23,
#                             "id": "Q23"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 84,
#                             "id": "Q84"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 900,
#                             "id": "Q900"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# date of creation 	 P32 Q21 Q40 Q106
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "date of creation"
#         },
#         "de": {
#             "language": "de",
#             "value": "Erstellungsdatum"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "date de cr\u00e9ation"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 40,
#                             "id": "Q40"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 21,
#                             "id": "Q21"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 106,
#                             "id": "Q106"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# date of modification 	 P33 Q21 Q897 Q106
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "date of modification"
#         },
#         "de": {
#             "language": "de",
#             "value": "\u00c4nderungsdatum"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "date de modification"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 897,
#                             "id": "Q897"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 21,
#                             "id": "Q21"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 106,
#                             "id": "Q106"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# editor 	 P34 Q23 Q897 Q95
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "editor"
#         },
#         "de": {
#             "language": "de",
#             "value": "Bearbeiter"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "editor"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 897,
#                             "id": "Q897"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 23,
#                             "id": "Q23"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 95,
#                             "id": "Q95"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }
# status 	 P35 Q70 Q67 Q158
# {
#     "labels": {
#         "en": {
#             "language": "en",
#             "value": "status"
#         },
#         "de": {
#             "language": "de",
#             "value": "Status"
#         },
#         "fr": {
#             "language": "fr",
#             "value": "statut"
#         }
#     },
#     "descriptions": {
#         "en": {
#             "language": "en",
#             "value": "Lux SAF Property"
#         }
#     },
#     "claims": {
#         "P4": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P4",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 67,
#                             "id": "Q67"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P5": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P5",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 70,
#                             "id": "Q70"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ],
#         "P50": [
#             {
#                 "mainsnak": {
#                     "snaktype": "value",
#                     "property": "P50",
#                     "datavalue": {
#                         "value": {
#                             "entity-type": "item",
#                             "numeric-id": 158,
#                             "id": "Q158"
#                         },
#                         "type": "wikibase-entityid"
#                     },
#                     "datatype": "wikibase-item"
#                 },
#                 "type": "statement",
#                 "rank": "normal",
#                 "qualifiers": {},
#                 "qualifiers-order": [],
#                 "references": []
#             }
#         ]
#     },
#     "aliases": {},
#     "sitelinks": {}
# }

# %% [markdown]
# # DM_rules properties not part of the sourced CIDOC CRM
# This is temporarily fix and needs to be revisited once settled on a stable version of CIDOC CRM

# %%
propertyID = dict()
query = "PREFIX wdt: <http://{}.wiki.opencura.com/prop/direct/> SELECT ?item ?label WHERE {{?item rdfs:label ?label }}".format(wbstack)
wdi_core.WDItemEngine.execute_sparql_query(query, as_dataframe = True, endpoint=sparql)
for index, row in wdi_core.WDItemEngine.execute_sparql_query(query, as_dataframe = True, endpoint=sparql).iterrows():
    propertyID[row["label"]] =row["item"].replace(entityUri, "")

# %%
missing_classes = ['R8 consists of', "E13 Attribute assignement", 'E52 Time-span', 'P48 has prefered identifier', 'P107 has current or former member of']
for missing_class in missing_classes:
    statements=[]
    statements.append(wdi_core.WDItemID(value=qid["Class"], prop_nr=propertyID["instance of"]))
    statements.append(wdi_core.WDUrl(value="http://erlangen-crm.org/current/"+ missing_class.replace(" ", "_"), prop_nr=propertyID['exact match']))
    item = localEntityEngine(new_item=True, data=statements)
    item.set_label(missing_class , lang="en")
    print(item.write(login))
# Out:
# /usr/local/lib/python3.9/site-packages/wikidataintegrator/wdi_core.py:175: UserWarning: mapping relation types are being ignored
#   warnings.warn("mapping relation types are being ignored")
# Q897
# Q898
# Q899
# Q900
